# %% [markdown]
# Q1: Understanding Central Tendency (Easy)
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
# -> Step 1: Identify the Data
# The bakery’s daily muffin sales (in dozens) are:
#
# 10
# ,
# 12
# ,
# 11
# ,
# 15
# ,
# 14
# ,
# 13
# ,
# 12
#  Calculate Measures of Central Tendency
# Mean (average):
# 10
# +
# 12
# +
# 11
# +
# 15
# +
# 14
# +
# 13
# +
# 12
# 7
# =
# 87
# ≈12.43
#
# So, the mean is about 12.4 dozens.
#
# Median (middle value):
# Ordered data:
#
# 10
# ,
# 12
# ,
# 12
# ,
# 13
# ,
# 14
# ,
# 15
# The middle value is 12.
#
# Mode (most frequent value):
# The value 12 appears twice, more than any other number.
# So, the mode is 12.
#
#  Decide the Most Representative Value
# From the assignment’s context, the goal is to find the best single number that represents the weekly sales.
#
# The mean gives a precise average (12.4), but it’s not a whole number.
#
# The median and mode both point to 12, which is a clean, realistic figure for dozens of muffins.Since the data is fairly balanced (no extreme outliers), the mean and median are close, but 12 (median/mode) is the most practical representative value.
#
#
# The most representative value of the bakery’s weekly muffin sales is 12 dozens.
# This is because both the median and mode equal 12, and the mean (12.4) is very close. Together, they show that the bakery typically sells about 12 dozens per day, making it the best summary of their weekly sales.
# Q2: Mean in Real Life (Easy)
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
# -> Step 1: Identify the Data
# The quiz scores are:
#
# 12
# ,
# 15
# ,
# 14
# ,
# 16
# ,
# 18
# ,
# 20
# ,
# 19
#  Calculate the Mean
# To find the mean (average):
#
# Mean
# =
# 12
# +
# 15
# +
# 14
# +
# 16
# +
# 18
# +
# 20
# +
# 19
# 7
# =
# 114
# 7
# ≈
# 16.3
# So, the mean score is 16.3 marks.Step 3: Interpret the Result
# Based on the page’s teaching style, the mean is used as a summary measure of central tendency:
#
# It tells us the typical performance of the class.
#
# Since the mean is around 16 out of 20, it shows that most students scored fairly high.
#
# This suggests the class, as a whole, performed well on the quiz.
#
# The mean smooths out individual differences (some scored lower like 12, others higher like 20) and gives a single representative value.✅ Final Explanation
# The mean score is 16.3, which indicates that the class’s overall performance was strong. In real life, teachers use the mean to quickly gauge how well the group did, rather than focusing only on individual highs and lows.
# Q3: Mode in Real Life (Easy)
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
# ->  Identify the Data
# The shoe sizes sold are:
#
# 7
# ,
# 8
# ,
# 9
# ,
# 8
# ,
# 8
# ,
# 10
# ,
# 7
# ,
# 9
#  Find the Mode
# Count frequencies:
#
# Size 7 → appears 2 times
#
# Size 8 → appears 3 times
#
# Size 9 → appears 2 times
#
# Size 10 → appears 1 time
#
# The store sold size 8 shoes most frequently.
#
# This tells the manager that size 8 is in highest demand.
#
# Knowing the mode helps with inventory planning: the manager can stock more size 8 shoes to meet customer needs.
#
# It also reduces the risk of running out of the most requested size, improving customer satisfaction and sales.Step 3: Interpret the Result
# Based on the page’s teaching style, the mode is emphasized as the most popular or common value:
#
# The store sold size 8 shoes most frequently.
#
# This tells the manager that size 8 is in highest demand.
#
# Knowing the mode helps with inventory planning: the manager can stock more size 8 shoes to meet customer needs.
#
# It also reduces the risk of running out of the most requested size, improving customer satisfaction and sales.The mode is the value that occurs most often.
# → Mode = 8 Step 3: Interpret the Result
# Based on the page’s teaching style, the mode is emphasized as the most popular or common value:
#  Q4: Median in Real Life (Medium)
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median
# -> Identify the Data
# The car prices are:
#
# $8,000, $9,500, $10,200, $11,000, $50,000
# Calculate the Mean
# Mean
# =
# 8000
# +
# 9500
# +
# 10200
# +
# 11000
# +
# 50000
# 5
# =
# 88700
# 5
# =
# 17
# ,
# 740
# So, the mean price is $17,740.Why the Mean is Misleading
# The mean is pulled upward by the very high outlier ($50,000).
#
# This makes the average look much higher than what most cars actually cost.
#
# If the dealer relied only on the mean, they might think typical cars are nearly $18,000, which doesn’t reflect reality.
#
#  Calculate the Median
# Ordered data:
#
# $8,000, $9,500, $10,200, $11,000, $50,000
# The middle value is $10,200.
# So, the median = $10,200.Why the Median is Better
# The median is not affected by extreme values.
#
# It shows the true middle price, which is much closer to what most cars cost.
#
# For the dealer, the median gives a more realistic picture of the market and helps in setting fair expectations for customers.
#
#
# The median price is $10,200, and it’s a better measure than the mean because the mean is distorted by the $50,000 outlier. The median reflects the typical car price more accurately, making it the more useful statistic for the dealer’s decision-making.
# Q5: Dispersion Introduction (Medium)
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?
# -> Identify the Data
# Puzzle completion times (in minutes):
#
# 25
# ,
# 30
# ,
# 27
# ,
# 35
# ,
# 40
# 📈 Step 2: Calculate the Range
# Range
# =
# Maximum
# −
# Minimum
# =
# 40
# −
# 25
# =
# 15
# So, the range is 15 minutes.
#
#  Interpret the Result
# From the page’s teaching style, the range is introduced as the simplest measure of dispersion:the page’s teaching style, the range is introduced as the simplest measure of dispersion:
#
# It shows the spread of the data — how much the times vary from the fastest to the slowest attempt.
#
# A range of 15 minutes means the student’s puzzle-solving time can differ quite a lot depending on the day.
#
# This variation suggests that the student’s performance is not perfectly consistent; sometimes they finish quickly (25 minutes), other times it takes much longer (40 minutes).
#
# In real life, the range helps us understand stability vs. fluctuation in performance.The range is 15 minutes, and it tells us that the student’s puzzle-solving time varies significantly across days. This highlights the inconsistency in performance, showing that while some days are efficient, others take much longer.
# Q6: Range in Action (Medium)
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging?
# Weekly apple harvest weights (kg):
#
# 100
# ,
# 105
# ,
# 98
# ,
# 110
# ,
# 120
# 📈 Step 2: Calculate the Range
# Range
# =
# Maximum
# −
# Minimum
# =
# 120
# −
# 98
# =
# 22
# So, the range is 22 kg.
#
#  Interpret the Result
# From the page’s teaching style, the range is introduced as a measure of dispersion that shows how spread out the data is:The farmer’s harvest varies by 22 kg from the smallest to the largest weekly total.
#
# This tells us there is noticeable fluctuation in weekly harvest weights.
#
# For packaging, this information is useful because:
#
# The farmer can plan for flexible packaging sizes to accommodate weeks with higher yields.
#
# It helps avoid shortages (if packaging is too small for larger harvests) or waste (if packaging is too large for smaller harvests).
#
# Knowing the variation allows the farmer to optimize storage and distribution.The range is 22 kg, and it helps the farmer understand how much the harvest weight can vary week to week. This insight is practical for packaging and logistics planning, ensuring that packaging capacity matches the fluctuations in harvest size.
# Q7: Variance for Decision-Making (Medium)
# Two delivery companies track delivery delays (in minutes).
# Company A: variance = 6
# Company B: variance = 15
# Which company is more consistent, and why?
# -> Recall What Variance Means
# Variance measures how spread out the data is around the mean.
#
# A smaller variance means values are closer to the average → more consistency.
#
# A larger variance means values are more spread out → less consistency.
#  Compare the Two Companies
# Company A: Variance = 6 → delays are relatively close to the average.
#
# Company B: Variance = 15 → delays vary much more widely.Since Company A has the lower variance, its delivery times are more consistent.
#
# Customers can expect fewer surprises with Company A because delays don’t fluctuate as much.
#
# Company B’s higher variance means delivery delays are less predictable, which could affect reliability.Company A is more consistent because its variance (6) is smaller than Company B’s (15). Lower variance indicates steadier performance, making Company A more reliable in terms of delivery delays.
# Q8: Standard Deviation in Context (Hard)
# A finance student compares the daily price fluctuations of two cryptocurrencies.
# Coin A: standard deviation = $30
# Coin B: standard deviation = $120
# Which coin is riskier to invest in, and why?
# -> Recall What Standard Deviation Means
# Standard deviation measures how much values deviate from the mean.
#
# A small standard deviation → prices stay close to the average → more stability.
#
# A large standard deviation → prices swing widely → more volatility and risk.
#
# 📈 Step 2: Compare the Two Coins
# Coin A: Standard deviation = $30 → relatively small fluctuations.
#
# Coin B: Standard deviation = $120 → much larger fluctuations.Interpret the Result
# Since Coin B’s standard deviation is four times larger, its daily price changes are much more unpredictable.
#
# This makes Coin B riskier to invest in, because investors face greater uncertainty about returns.
#
# Coin A, with smaller deviations, is more stable and less risky.Coin B is riskier because its standard deviation ($120) is much higher than Coin A’s ($30). A higher standard deviation means greater volatility, so Coin B’s price is less predictable and carries more investment risk.
# Q9: Combining Measures (Hard)
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
# -> Monthly electricity usage (in kWh):
#
# 400
# ,
# 420
# ,
# 390
# ,
# 450
# ,
# 410
# 📈 Step 2: Calculate Central Tendency
# Mean (average):
# 400
# +
# 420
# +
# 390
# +
# 450
# +
# 410
# 5
# =
# 2070
# 5
# =
# 414
#
# So, the mean usage is 414 kWh.
#
# Median (middle value):
# Ordered data:390
# ,
# 400
# ,
# 410
# ,
# 420
# ,
# 450
# The middle value is 410 kWh.
#
# Mode (most frequent value):
# Each value occurs only once → no mode.
#  Calculate Dispersion
# Range:
# Max
# −
# Min
# =
# 450
# −
# 390
# =
# 60
#
# So, the range is 60 kWh.
# This shows the spread of usage across months.Interpret the Result
# The page emphasizes combining measures to get a fuller picture:
#
# The mean (414) shows the typical monthly usage.
#
# The median (410) confirms that the central value is close to the mean, suggesting balanced data.
#
# The range (60) shows there is some variation, but not extreme.
#
# Together, these measures tell the family their electricity usage is fairly consistent, usually around 410–414 kWh per month, with fluctuations of about ±30 kWh.By combining measures of central tendency (mean, median) and dispersion (range), the family sees that their electricity usage is stable and predictable. This helps them plan budgets and anticipate bills more accurately, rather than relying on just one measure.
# Q10: Practical Application (Hard)
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?
# -> Identify the Data
# Points scored in 8 games:
#
# 15
# ,
# 18
# ,
# 20
# ,
# 22
# ,
# 25
# ,
# 17
# ,
# 19
# ,
# 21
# 📈 Step 2: Calculate Central Tendency
# Mean (average):
# 15
# +
# 18
# +
# 20
# +
# 22
# +
# 25
# +
# 17
# +
# 19
# +
# 21
# 8
# =
# 157
# 8
# =
# 19.6
#
# So, the mean is 19.6 points.15
# +
# 18
# +
# 20
# +
# 22
# +
# 25
# +
# 17
# +
# 19
# +
# 21
# 8
# =
# 157
# 8
# =
# 19.6
#
# So, the mean is 19.6 points.
#
# Median (middle value):
# Ordered data:
#
# 15
# ,
# 17
# ,
# 18
# ,
# 19
# ,
# 20
# ,
# 21
# ,
# 22
# ,
# 25
# Middle two values = 19 and 20 →
# 19
# +
# 20
# 2
# =
# 19.5
#
# So, the median is 19.5 points.
#
# Mode (most frequent value):
# Each score occurs once → no mode.Calculate Dispersion
# Range:
# Max
# −
# Min
# =
# 25
# −
# 15
# =
# 10
#
# So, the range is 10 points.
#
# Standard Deviation:
# Measures how spread out scores are around the mean.
# Approximate calculation: 3.16 points.
# This means most scores are within about ±3 points of the average.Interpret the Result
# From the page’s teaching style, combining measures gives a complete performance picture:
#
# The mean (19.6) and median (19.5) are very close → scoring is balanced and consistent.
#
# The range (10) shows some variation, but not extreme.
#
# The standard deviation (~3.16) indicates scores cluster tightly around the average, showing steady performance.
#
# No mode → the player doesn’t repeatedly score the same number, but stays within a consistent band.The player’s scoring performance is consistent and reliable, averaging about 20 points per game with only moderate variation. These measures together show that the player is a steady contributor, rarely having extreme highs or lows, which is valuable for team planning and strategy.
